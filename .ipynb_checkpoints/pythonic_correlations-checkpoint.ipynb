# %%
from default_values import *
import default_values
reload(default_values)

from functions_corr import *
import functions_corr
reload(functions_corr)

from functions_frag import *
import functions_frag
reload(functions_frag)

from functions_compare import *
import functions_compare
reload(functions_compare)

import numpy as np
import math
import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

import ROOT
# Out:
# ['InputData/pp_SE_L0_Correlation_GMB_Ratio_Track.root', 'InputData/pPb_SE_L0_Correlation_GMB_Ratio_Track.root']

# %%
Corrs = ROOT_to_nparray()

# %%
if not(Ped_Sub_First):
    print Corrs["p-Pb_CSR"][1][1]
    Correlated_Subtraction(Corrs)
    print Corrs["p-Pb_CSR"][1][1]
# Out:
# [ 0.2528128   0.25348571  0.25275979  0.27388594  0.29159715  0.32458884
#   0.35829105]
# [-0.01389411  0.01175083  0.          0.01946078  0.03900003  0.06098007
#   0.10377706]

# %%
#Plot_UB()
Plot_UB_Subtraction(Corrs)
#Plot_Sub_UB_Overlay(Corrs)
# Out:
#
#                                        PROTON-PROTON
#
#
#                                        PROTON-LEAD

# %% [markdown]
# $C_S = \frac{C_{SR} - (1-p) C_{BR}}{p}$

# %%
if (Ped_Sub_First):
    Correlated_Subtraction(Corrs)

# %%
#Plot_pp_pPb_Cs(Corrs)

# %% [markdown]
# Propagate Absolute Uncertianty arising from purity: $ C_s = \frac{A}{p} \rightarrow \frac{\Delta C_s}{Cs} = \frac{\Delta p}{p}$

# %%
reload(functions_frag)
from functions_frag import *

# %%
Frags = Get_Fragmentation(Corrs)

# %%
Plot_FF(Frags)

# %% [markdown]
# ## p-Pb / pp

# %%
FF_Ratio(Frags)

# %%
Overlay_pT_FF(Frags)
# Out:
#                              PROTON-PROTON:
# Central Values
# [[ 6.54768238  5.16064498  2.19855175  0.65295414  0.42038503  0.10425787]
#  [ 3.86482649  1.53141984  1.5559198   0.55007196  0.32635716  0.0458088 ]
#  [ 8.91844302  3.92025832  2.43748646  0.59170802  0.24401526  0.08064878]
#  [ 5.97160749  4.03103599  2.49681887  0.56981401  0.15426946  0.03623773]]
# Statistical Errors (Relative)
# [[ 0.21200115  0.14875957  0.17101561  0.25276758  0.17285106  0.27906188]
#  [ 0.30367697  0.40874583  0.18749999  0.2333501   0.18316446  0.47930238]
#  [ 0.12551095  0.14110127  0.10659167  0.2032276   0.20531639  0.19467035]
#  [ 0.24411126  0.19062493  0.146959    0.30099244  0.39075437  0.80124526]]
# Relative Uncertainty from Purity
# [[ 1.01439179  0.79950669  0.34060798  0.10115813  0.06512764  0.01615202]
#  [ 0.40974088  0.16235795  0.16495539  0.05831749  0.03459971  0.00485655]
#  [ 0.77826787  0.34210131  0.21270724  0.0516354   0.02129399  0.00703782]
#  [ 0.49757335  0.33587876  0.2080429   0.04747872  0.01285422  0.00301944]]
#                               PROTON-LEAD:
# Central Values
# [[  8.37397076   6.2455793    2.4969475    0.909404     0.41559619
#     0.09376731]
#  [ 12.43055825   4.97320794   3.02657692   0.76613249   0.29097736
#     0.03338327]
#  [ 10.39947414   5.2611943    2.23616847   0.70330504   0.2504134
#     0.0491681 ]
#  [ 13.16464564   4.46507605   2.01412625   0.76176436   0.18615515
#     0.08963693]]
# Statistical Errors (Relative)
# [[ 0.1910522   0.14068897  0.1671382   0.19179277  0.15599758  0.2394174 ]
#  [ 0.11190047  0.14249255  0.10343744  0.16637191  0.16461205  0.48915171]
#  [ 0.11529424  0.11092435  0.109053    0.14738335  0.13703999  0.22637023]
#  [ 0.10728509  0.15191498  0.13509952  0.14282311  0.21735732  0.33516522]]
# Relative Uncertainty from Purity
# [[ 1.29732731  0.96758884  0.38683658  0.14088832  0.06438574  0.01452679]
#  [ 1.31786199  0.52724918  0.3208714   0.08122378  0.03084882  0.00353922]
#  [ 0.90751004  0.45911808  0.19513923  0.06137391  0.02185232  0.00429065]
#  [ 1.0969202   0.37204435  0.16782341  0.06347263  0.01551104  0.00746883]]

# %% [markdown]
# **Weigthed Average:** $\frac{\sum_{i=1}^{n}w_i x_i}{\sum_{i=1}^{n}w_i}$ where weight $w_i = \frac{1}{\sigma_i^2} $ and $\sigma_i = \sqrt{\sigma_{i,stat_{rel}}^2 + \sigma_{i,purity_{rel}}^2}$ , in each $z_\mathrm{T}$ bin (i). **Important:** The relative uncertainties are used in weighting

# %%
Combined_Frags = Average_FF(Frags)

# %%
Plot_pp_pPb_Avg_FF(Combined_Frags)
# Out:
#                     pp Central Values:
# [ 7.3631484   4.10534616  2.27031611  0.58889028  0.31167469  0.08307405]
#
#                     pp Stat. Uncertainty:
# [ 0.64625409  0.3425662   0.16367214  0.07398993  0.03061581  0.01229354]
#
#                     p-Pb Central Values:
# [ 11.65605997   5.16578367   2.44308733   0.7666258    0.28231594
#    0.06375457]
#
#                     p-Pb Stat. Uncertainty:
# [ 0.70386428  0.36011746  0.15923387  0.06578824  0.02412502  0.01059808]
#
#                         LaTeX Table
# Source   &  pp data & \pPb~data  \\
# Statistical Uncertainty & 7\%-15\% & 6\%-17\% \\
# \hline
# Purity & 5\%-6\% & 5\%-7\% \\
# Tracking Efficiency &  5\% & 5\%  \\

# %%
reload(functions_compare)
from functions_compare import *

# %%
pp_pPB_Avg_Ratio(Combined_Frags,0)
# Out:
#                 Central Values:
# [ 1.58302663  1.25830648  1.07610007  1.30181433  0.90580323  0.76744265]
#
#                 Ratio Uncertainty from Purity:
# [ 0.05872537  0.07588735  0.07593068  0.07493072  0.09648936  0.09926891]
#
#                 Ratio Uncertainty from Single Track Efficiency:
# [ 0.11193689  0.0889757   0.07609177  0.09205217  0.06404996  0.05426639]
#
#                 Full Systematic Uncertainty:
# [ 0.12640623  0.11694257  0.10749616  0.11869379  0.11581275  0.11313336]
#
# ****************************************
# Minimizer is Linear
# Chi2                      =     0.433724
# NDf                       =            5
# p0                        =      1.14875   +/-   0.120239

# %%
Ratio_Error =  np.sqrt(Combined_Frags["p-Pb_Combined_FF_Errors"]**2 + Combined_Frags["pp_Combined_FF_Errors"]**2)
Ratio =(Combined_Frags["p-Pb_Combined_FF"]/Combined_Frags["pp_Combined_FF"])
from ROOT import TGraphErrors
Ratio_Fit_Plot = ROOT.TGraphErrors()
for izt in range (0,len(Ratio)):
    Ratio_Fit_Plot.SetPoint(izt,zT_centers[izt],Ratio[izt])
    Ratio_Fit_Plot.SetPointError(izt,0,Ratio_Error[izt])

#zt_error = np.ones_like(zT_centers)
#TGraph_Ratio = TGraphErrors(Ratio.size-zT_offset,zT_centers[zT_offset:],
#                            Ratio[zT_offset:],Ratio_Error[zT_offset:])    
Ratio_Fit_Plot.Fit("pol0","S")
#f = Ratio_Fit_Plot.GetFunction("pol0")
#print f.GetNDF()
#print f.GetChisquare()    
#print f.GetProb()
#print f.GetParameter(0)
#print f.GetParError(0)
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      40.0578
# NDf                       =            5
# p0                        =     0.801148   +/-   0.0147759
# tab completion not implemented for this context
#
# tab completion not implemented for this context
