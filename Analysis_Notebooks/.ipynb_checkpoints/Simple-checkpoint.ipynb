# %%
from default_values import *
import default_values
reload(default_values)

from functions_root_nparray import *
import functions_root_nparray
reload(functions_root_nparray)

from functions_correlations import *
import functions_correlations
reload(functions_correlations)

from functions_fragmentation import *
import functions_fragmentation
reload(functions_fragmentation)

import numpy as np
from numpy import geomspace
import math
import matplotlib
from cycler import cycler

import matplotlib.pyplot as plt
# %matplotlib inline

import ROOT
# Out:
# Welcome to JupyROOT 6.14/04
# ../InputData/zT_Rebin_8_006zT06zT13fnew/pp_SE_L0_Correlation_GMB_Ratio.root
# ['pp', 'p-Pb']
# [[0.18152603]
#  [0.11831406]]
# ../InputData/zT_Rebin_8_006zT06zT13fnew/pp_SE_L0_Correlation_GMB_Ratio.root
# ['pp', 'p-Pb']
# [[0.18152603]
#  [0.11831406]]

# %%
print(purity["p-Pb"])
print(Rel_pUncert["p-Pb"])
# Out:
# [0.28020939]
# [0.11831406]

# %% [markdown]
# **root to numpy**
#
# **Correlated Subtraction**: $C_S = \frac{C_{SR} \ \ - \ \ (1-p) C_{BR}}{p}$
#
# **Pedestal Subtraction**

# %%
Corrs = ROOT_to_nparray()
#Plot_Sub_UB_Overlay(Corrs)
Correlated_Subtraction_Weights(Corrs)
Ped_Sub_After_Cs(Corrs)
Plot_pp_pPb_Cs_Individual(Corrs)
# Out:
# pPb BR:
# [1.99110604 1.98528038 1.84919159 1.89056362 2.06157899 2.24929477
#  2.45552084 2.62391013]
#
#  pPb Cs
# [-0.09082878 -0.05065768  0.00508236  0.04557532  0.02734174  0.06946749
#   0.15753437  0.19332425]
#
#
# [0.23556051 0.19116639 0.15070418 0.14799442 0.16388341 0.18613048
#  0.19479098 0.24817602]
# pPb BR:
# [1.63378412 1.58363012 1.45140782 1.5485247  1.65565388 1.7942222
#  2.00981733 2.16734288]
#
#  pPb Cs
# [-0.04528214 -0.0283082   0.03138094 -0.00307274  0.09965733  0.11031969
#   0.15532141  0.19482658]
#
#
# [0.19093759 0.14879327 0.11886411 0.12178206 0.12032612 0.13357938
#  0.16822763 0.19912896]
# pPb BR:
# [1.07444208 1.02932198 0.93389804 0.96060097 1.06970342 1.14675529
#  1.34283743 1.58561648]
#
#  pPb Cs
# [-0.08664402 -0.01137794  0.01312505 -0.00174711  0.03467865  0.05076254
#   0.07560012  0.11824859]
#
#
# [0.11380851 0.0947198  0.06950554 0.07413079 0.08558145 0.09160685
#  0.120146   0.160323  ]
# pPb BR:
# [0.638618   0.62938847 0.56242907 0.55329299 0.65891278 0.72551283
#  0.85520782 1.06159695]
#
#  pPb Cs
# [-0.03799592 -0.01082117  0.0009252   0.00989596  0.0043013   0.03160514
#   0.07480405  0.1240486 ]
#
#
# [0.05046564 0.05366946 0.03691206 0.03576616 0.0491761  0.05505879
#  0.08066461 0.12099297]
# pPb BR:
# [0.2787212  0.3027009  0.27967398 0.27443988 0.31053434 0.37029315
#  0.49281311 0.65926425]
#
#  pPb Cs
# [-0.03616485 -0.0037354  -0.0087106   0.012446    0.02920313  0.02113984
#   0.03229853  0.07601445]
#
#
# [0.02461221 0.02483226 0.02254471 0.02376529 0.03100377 0.03471018
#  0.05383166 0.07899914]
# pPb BR:
# [0.09939283 0.11652998 0.10564717 0.11151808 0.12850677 0.16436159
#  0.23647583 0.36868932]
#
#  pPb Cs
# [-0.01281026 -0.0029415  -0.00233008  0.00527158  0.00498657  0.00569433
#   0.04056768  0.04226763]
#
#
# [0.00732183 0.0150242  0.00774081 0.00979475 0.01318645 0.02021727
#  0.02684684 0.05361241]
# pPb BR:
# [0.0356751  0.04403504 0.03752523 0.03993233 0.04762811 0.07215223
#  0.11030038 0.20157805]
#
#  pPb Cs
# [-0.0051188  -0.00026905  0.00104922 -0.00078017  0.00071649  0.00258669
#   0.01084058  0.02241769]
#
#
# [0.00388775 0.0049518  0.0044426  0.00543149 0.00522395 0.00949522
#  0.01861243 0.03076429]
# pPb BR:
# [0.01428166 0.01875007 0.01556436 0.01424812 0.01929096 0.03265897
#  0.05180127 0.10758349]
#
#  pPb Cs
# [ 1.08590041e-03  1.48698356e-05  3.07567255e-03 -3.09054239e-03
#   4.70434263e-03 -2.72550345e-03  1.10843241e-02  1.22036037e-02]
#
#
# [0.00077311 0.0011708  0.00158357 0.00490278 0.00373739 0.00430593
#  0.00914156 0.01763248]

# %%
Frags = Get_Fragmentation(Corrs)
#LaTeX_Results_Summary(Frags)
#LaTeX_Ratio_Systematics(Frags)

# %%
reload(functions_fragmentation)
from functions_fragmentation import *

# %%
Combined_Frags = Average_FF(Frags)
Plot_pp_pPb_Avg_FF_and_Ratio(Combined_Frags)
#print_from_Dict(Frags)
# Out:
# ****************************************
# Minimizer is Linear
# Chi2                      =      5.89525
# NDf                       =            7
# p0                        =     0.836787   +/-   0.113667

# %% [markdown]
# ## HEP

# %%
for table in submission.tables:
    table.keywords["cmenergies"] = [5020]
outdir = "HEP_FILES"
submission.read_abstract("abstract.txt")
submission.create_files(outdir)
# !ls submission.tar.gz
# !ls HEP_FILES
# Out:
# submission.tar.gz
# Cs_Final_Indv_pT_0_zT_0.png         figure_5_bottom_panel.yaml
# Cs_Final_Indv_pT_0_zT_3.png         figure_5_bottom_pannel.yaml
# Cs_Final_Indv_pT_0_zT_7.png         figure_5_top_panel.yaml
# Final_FFunction_and_Ratio.png       figure_5_top_pannel.yaml
# figure_4_z_\mathrm{t}_bin_0.yaml    submission.yaml
# figure_4_z_\mathrm{t}_bin_3.yaml    thumb_Cs_Final_Indv_pT_0_zT_0.png
# figure_4_z_\mathrm{t}_bin_7.yaml    thumb_Cs_Final_Indv_pT_0_zT_3.png
# figure_4_zt_bin_0.yaml              thumb_Cs_Final_Indv_pT_0_zT_7.png
# figure_4_zt_bin_3.yaml              thumb_Final_FFunction_and_Ratio.png
# figure_4_zt_bin_7.yaml

# %%
from hepdata_validator.data_file_validator import DataFileValidator

data_file_validator = DataFileValidator()

# the validate method takes a string representing the file path
data_file_validator.validate(file_path='HEP_FILES/figure_5_top_pannel.yaml')

# if there are any error messages, they are retrievable through this call
data_file_validator.get_messages()

# the error messages can be printed
data_file_validator.print_errors('HEP_FILES/figure_5_top_pannel.yaml')

# %%
reload(functions_correlations)
from functions_correlations import *

# %%
Frags["p-Pb_purity_FF_Errors"][0]/Frags["p-Pb_FF"][0]
# Out:
# array([0.11268006, 0.11268006, 0.11268006, 0.11268006, 0.11268006,
#        0.11268006, 0.11268006, 0.11268006])

# %%
LaTeX_Results_Summary(Frags)
# Out:
# [[0.9608766  0.60245435 0.36791211 0.20791283 0.10969077 0.05580942
#   0.02760709 0.01445976]]
#                         LaTeX Table
# 0
# 4
# 5
# 7
# Source   &  pp data & p--Pb data  \\
# Statistical Uncertainty & 19\%-40\% & 28\%-43\% & 16\%-23\% & 27\%-34\% \\
# \hline
# Purity & 18\%-18\% & 18\%-18\% & 11\%-11\% & 11\%-11\% \\
# UE & 8\%-15\% & 7\%-12\% & 7\%-9\% & 8\%-9\% \\
# Tracking Efficiency &  5.6\% & 5.6\%  \\
# Total Sys & 21\%-24\% & 20\%-22\% & 14\%-16\% & 15\%-15\% \\
# Total Uncertainty & 28\%-47\% & 34\%-48\% & 22\%-27\% & 31\%-37\% \\

# %%
#pp_pPB_Avg_Ratio(Combined_Frags,0)

# %%
#LaTeX_Table(Combined_Frags)

# %%
#Compare_FF_Integration([2.7,2.356,1.57],["7\pi/8","3\pi/4","\pi/2"])

# %% [markdown]
# #
